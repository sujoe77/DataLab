# %%
# %load_ext autoreload
# %autoreload 2
from Scraper import scrape_reviews

df = scrape_reviews(PATH = 'https://www.trustpilot.com/review/flixbus.com?languages=all&page=', n_pages = 1)
df.head(20)
#df.describe()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# https://www.trustpilot.com/review/flixbus.com?languages=all&page=1&stars=1
# 20
#                        Name  \
# 0          Sanae EL HABBARI
# 1            aksel koseoglu
# 2              Peter Zejlon
# 3   ZackSebas BallardIbarra
# 4                        Mo
# 5                   Bosko R
# 6                   Larissa
# 7                      Axel
# 8                   Raj Par
# 9              Emil Birkesø
# 10                   Raquel
# 11                sam allos
# 12       Marita Sederström
# 13            Silvia Maglie
# 14          Travis Morrison
# 15              Per Laukamp
# 16          Thai Wildboar13
# 17                        .
# 18              Jitka Balcı
# 19          Katarina kamlin
#
#                                                Header  \
# 0                No seat allocated to some passengers
# 1   Bus arrived 1h50 min late and didn't stop at t...
# ...
