# %%
name = 'Eric'
print(f'Hello, {name}!')

number: str = '232sd'
print(f'The number is {number}.')

# %%
bicycles = ['trek', 'cannondale', 'redline', 'specialized']
print(bicycles)
print(bicycles[0])
del bicycles[0]
print(bicycles)
