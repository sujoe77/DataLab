# %%
import datetime
import pandas as pd

EXECLUDE_TITLE = ["frontend", "C#", "udvikler", "android", "analyst", "devops", "security", "sale", "java"]

def ex_filter(title, exList):
    for keyword in exList:
        if(keyword.lower() in title.lower()):
            #print("------------>" + keyword + " found in " + title)
            return 0
    return 1

df = pd.read_csv('jobs_20190505191528.csv')
#df_new = df[df["Title"].str.contains("c#")]
df.head()
#new_df = df[~df["Title"].str.contains("#")]
#new_df = df[df["Title"].str.contains(EXECLUDE_TITLE)]
#new_df = df.loc[ex_filter(df["Title"].str.lower(), EXECLUDE_TITLE)]
#new_df 
#df_new = df[ex_filter(df["Title"].str.lower(), EXECLUDE_TITLE)]
#df_new
#df[df['Title'].isin(EXECLUDE_TITLE)]
#df[df['Title'].str.lower() in ([x.lower() for x in EXECLUDE_TITLE])]
#df
#df.sort_values(by=['Title'])
#new_df.sort_values(by=['Title'])
#new_df
# Out:
#                                                Title  \
# 0                                 Lead Data Engineer
# 1  Backend Software Engineer - Experiments Platfo...
# 2                 Front-End/Client Software Engineer
# 3                                       Data Analyst
# 4  Solution Principal / Data Engineer – Big Data ...
#
#                                            Company  \
# 0                             A.P. Moller - Maersk
# 1                                            Agoda
# 2                                  GlobeSearch A/S
# 3  Bruel & Kjaer Sound & Vibration Measurement A/S
# 4                                   DXC Technology
#
#                                     Location         Time  \
# 0  Esplanaden 50_ Kobenhavn K_ 1084 1263_ DK   3 days ago
# 1                             Copenhagen_ DK   5 days ago
# 2        Copenhagen_ Capital Region_ Denmark   1 week ago
# 3             Nærum_ Capital Region_ Denmark  3 weeks ago
# ...
