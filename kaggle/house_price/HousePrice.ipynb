# %% [markdown]
# # Overview

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd

df = pd.io.parsers.read_csv(
    filepath_or_buffer='data/train.csv',
    #header=None,
    sep=',',
)

pd.set_option('display.max_columns', None)
df.head(20)
#df.describe()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# # Dimension reduction
# ## remove columns rows if heavily inbalanced

# %%
#for colmuns with too many null value, we can remove it
dfc=pd.DataFrame(df.count())
dfc[dfc.iloc[:, 0] < 300].sort_values(0)
# Out:
#                0
# PoolQC         7
# MiscFeature   54
# Alley         91
# Fence        281

# %%
#remove column if heavily in balanced, for example
def grpByCount(colName):
    return df.groupby(colName)['Id'].count()
    
grpByCount('Utilities')
#grpByCount('MiscFeature')
#grpByCount('3SsnPorch')
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: Id, dtype: int64

# %% [markdown]
# ## Merge similar

# %% [markdown]
# * MoSold, YrSold
#
#
#
# * BsmtFullBath	int64
# * BsmtHalfBath	int64
# * FullBath	int64
# * HalfBath	int64
#
#
# * Condition1
# * Condition2
#
#
# * Exterior1st
# * Exterior2nd

# %% [markdown]
# ## Fill null values

# %%
## Merge

# %%
#dfc=pd.DataFrame(df.count())
#dfc[dfc.iloc[:, 0] < 1460].sort_values(0)
df.groupby('Utilities')['Id'].count()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: Id, dtype: int64

# %% [markdown]
# # Numeric values and Category values

# %%
dft=pd.DataFrame(df.dtypes)
dft[dft.iloc[:, 0] == 'object']
# Out:
#                     0
# MSZoning       object
# Street         object
# Alley          object
# LotShape       object
# LandContour    object
# Utilities      object
# LotConfig      object
# LandSlope      object
# Neighborhood   object
# Condition1     object
# Condition2     object
# BldgType       object
# HouseStyle     object
# RoofStyle      object
# RoofMatl       object
# Exterior1st    object
# Exterior2nd    object
# MasVnrType     object
# ExterQual      object
# ExterCond      object
# Foundation     object
# BsmtQual       object
# BsmtCond       object
# BsmtExposure   object
# BsmtFinType1   object
# BsmtFinType2   object
# Heating        object
# HeatingQC      object
# CentralAir     object
# Electrical     object
# KitchenQual    object
# Functional     object
# FireplaceQu    object
# GarageType     object
# GarageFinish   object
# GarageQual     object
# GarageCond     object
# PavedDrive     object
# PoolQC         object
# Fence          object
# ...

# %%
dft[dft.iloc[:, 0] != 'object']
# Out:
#                      0
# Id               int64
# MSSubClass       int64
# LotFrontage    float64
# LotArea          int64
# OverallQual      int64
# OverallCond      int64
# YearBuilt        int64
# YearRemodAdd     int64
# MasVnrArea     float64
# BsmtFinSF1       int64
# BsmtFinSF2       int64
# BsmtUnfSF        int64
# TotalBsmtSF      int64
# 1stFlrSF         int64
# 2ndFlrSF         int64
# LowQualFinSF     int64
# GrLivArea        int64
# BsmtFullBath     int64
# BsmtHalfBath     int64
# FullBath         int64
# HalfBath         int64
# BedroomAbvGr     int64
# KitchenAbvGr     int64
# TotRmsAbvGrd     int64
# Fireplaces       int64
# GarageYrBlt    float64
# GarageCars       int64
# GarageArea       int64
# WoodDeckSF       int64
# OpenPorchSF      int64
# EnclosedPorch    int64
# 3SsnPorch        int64
# ScreenPorch      int64
# PoolArea         int64
# MiscVal          int64
# MoSold           int64
# YrSold           int64
# SalePrice        int64

# %% [markdown]
# # Distribution
# ## Distribution of price

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

s = df['SalePrice'] 
x = np.floor(s / 1000)

#sns.distplot(s);
#x
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)
plt.xlabel('Price')
plt.ylabel('Probability')
plt.title('Histogram of SalePrice')
#plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([0, 765, 0, 0.01])
plt.grid(True)
plt.show()

n, bins, patches = plt.hist(x, 50, density=False, facecolor='g', alpha=0.75)
plt.axis([0, 765, 0, 200])
plt.show()

# %% [markdown]
# ## Distribution along feature

# %%
st_sp = df[['SaleCondition', 'SalePrice']]
#st_sp[st_sp['SaleType'] == 'WD'].describe()
st_sp.groupby(['SaleCondition']).mean().sort_values('SalePrice')
# Out:
#                    SalePrice
# SaleCondition
# AdjLand        104125.000000
# Abnorml        146526.623762
# Family         149600.000000
# Alloca         167377.416667
# Normal         175202.219533
# Partial        272291.752000

# %%
import matplotlib.pyplot as plt
x = df['SaleCondition'].replace(['AdjLand','Abnorml','Family','Alloca','Normal','Partial'],[1,2,3,4,5,6]) 
y = df['SalePrice']
plt.plot(x, y, 'ro')
plt.axis([0, 7, 0, 755000])
plt.show()

# %%
x = df['YrSold']
y = df['SalePrice']
plt.plot(x, y, 'ro')
plt.axis([2005, 2011, 0, 755000])
plt.show()

# %% [markdown]
# # Feture Groups
# * Area
# LotArea	int64
# MasVnrArea	float64
# GrLivArea	int64
# GarageArea	int64
# PoolArea	int64
#
# BsmtFinSF1	int64
# BsmtFinSF2	int64
# BsmtUnfSF	int64
# TotalBsmtSF	int64
# 1stFlrSF	int64
# 2ndFlrSF	int64
# LowQualFinSF	int64
# WoodDeckSF	int64
# OpenPorchSF	int64
#
# EnclosedPorch	int64
# 3SsnPorch	int64
# ScreenPorch	int64
#
# GarageCars
#
# * Time
# YearBuilt	int64
# YearRemodAdd	int64
# GarageYrBlt	float64
# MoSold	int64
# YrSold	int64
#
#
# * Category
# MSZoning
# MSSubClass
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Condition1
# Condition2
#
# BldgType
# HouseStyle
#
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
#
# MasVnrType
#
# Foundation
# Heating
# Electrical
# Functional
# GarageType
# GarageFinish
# PavedDrive
#
# SaleType	object
# SaleCondition	object
#
# * Geography
# Neighborhood
#
#
# * Rating
# PoolQC
# Fence
# GarageQual
# GarageCond
# ExterQual	object
# BsmtQual	object
# KitchenQual	object
#
#
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# OverallQual
# OverallCond
#
# ExterCond
#
# HeatingQC
# FireplaceQu
#
# * Binary
# CentralAir
#
#
# * Count
# BedroomAbvGr	int64
# KitchenAbvGr	int64
# TotRmsAbvGrd	int64
# Fireplaces	int64
# GarageCars	int64
#
# * Number
# LotFrontage
#
# * Other
# MiscVal	int64
# MiscFeature
